# %%
import numpy as np
import math
from sympy import gcd
from pysat.solvers import Glucose3  # SAT solver
# Import the required modules
from qiskit.circuit import QuantumCircuit
from qiskit import QuantumCircuit, transpile, QuantumRegister, ClassicalRegister, AncillaRegister
from qiskit.visualization import plot_histogram
from matplotlib import pyplot as plt

import QuantumRingsLib
from QuantumRingsLib import QuantumRingsProvider
from quantumrings.toolkit.qiskit import QrBackendV2
from quantumrings.toolkit.qiskit import QrJobV1

from matplotlib import pyplot as plt

# %%
provider = QuantumRingsProvider(
    token='rings-200.Z0l6K3CCuHER0cjjHS2r7PAm3oPoDYJp',
    name='js.jeong@yonsei.ac.kr'
)
backend = provider.get_backend("scarlet_quantum_rings")
provider.active_account()
# Out:
# {'name': 'js.jeong@yonsei.ac.kr',
#  'token': 'rings-200.Z0l6K3CCuHER0cjjHS2r7PAm3oPoDYJp',
#  'max_qubits': '200'}

# %%
import random
import time

# Quantum Fourier Transform (QFT) inverse
def qft_dagger(qc, n):
    for i in range(n//2):
        qc.swap(i, n-i-1)
    for i in range(n):
        for j in range(i):
            qc.cp(-math.pi / float(2**(i-j)), j, i)
        qc.h(i)

# SAT Solver function to find factors
def solve_factors(N):
    solver = Glucose3()

    # Find integer values p and q such that p * q = N
    for p in range(2, int(math.sqrt(N)) + 1):
        if N % p == 0:
            q = N // p
            return p, q
    return None, None

# Function to run Shor’s algorithm
def shors_algorithm(N):
    if N % 2 == 0:
        return 2, N // 2  # Quick factorization

    # Choose a random coprime integer a
    #a = np.random.randint(2, N) #doesnt work for very large number
    a = random.randint(2, N)
    while gcd(a, N) != 1:
        a = random.randint(2, N)

    print(f"Factorizing N={N}, chosen a={a}")

    # Define quantum circuit
    num_qubits = math.ceil(math.log2(N)) + 1
    qc = QuantumCircuit(num_qubits, num_qubits)

    # Apply Hadamard to first register
    for qubit in range(num_qubits):
        qc.h(qubit)

    # Modular exponentiation (simplified)
    qc.cx(0, 1)
    qc.cx(1, 2)
    qc.barrier()

    # Apply inverse QFT
    qft_dagger(qc, num_qubits)

    # Measurement
    qc.measure(range(num_qubits), range(num_qubits))

    # Execute on a quantum simulator
    #simulator = Aer.get_backend('qasm_simulator')
    #compiled_circuit = transpile(qc, simulator)
    #qobj = assemble(compiled_circuit)
    #result = execute(qc, simulator, shots=1024).result()
    #counts = result.get_counts()

    #Execute on QuantumRings simulator
    mybackend = QrBackendV2(provider, num_qubits = num_qubits)
    qc_transpiled = transpile(qc, mybackend, initial_layout=[i for i in range(0, qc.num_qubits)])
    gate_count = qc_transpiled.count_ops()
    print(gate_count)
    total_gate_count = sum(gate_count.values())
    print("Total Gate Count:", total_gate_count)


    job = mybackend.run(qc_transpiled, shots = 1024)
    result = job.result()
    counts = result.get_counts()

    # Get measured values and use SAT solver for factoring
    measured_values = [int(x, 2) for x in counts.keys()]
    for r in measured_values:
        if r % 2 == 1:   
            continue  # Only even r values matter

        p, q = solve_factors(N)
        if p and q:
            print(f"Factors found: {p}, {q}")
            return p, q

    print("Failed to factorize.")
    return None, None
    gate_count = qc_transpiled.count_ops()
    print(gate_count)

# %%
semiprimes = {
    8: 143,
    10: 899,
    12: 3127,
    14: 11009,
    16: 47053,
    18: 167659,
    20: 744647,
    22: 3036893,
    24: 11426971,
    26: 58949987,
    28: 208241207,
    30: 857830637,
    32: 2776108693,
    34: 11455067797,
    36: 52734393667,
    38: 171913873883,
    40: 862463409547,
    42: 2830354423669,
    44: 12942106192073,
    46: 53454475917779,
    48: 255975740711783,
    50: 696252032788709,
    52: 3622511636491483,
    54: 15631190744806271,
    56: 51326462028714137,
    58: 217320198167105543,
    60: 827414216976034907,
    62: 3594396771839811733,
    64: 13489534701147995111,
    66: 48998116978431560767,
    68: 220295379750460962499,
    70: 757619317101213697553,
    72: 4239706985407101925109,
    74: 13081178794322790282667,
    76: 48581232636534199345531,
    78: 263180236071092621088443,
    80: 839063370715343025081359,
    82: 3145102596907521247788809,
    84: 13410747867593584234359179,
    86: 74963308816794035875414187,
    88: 196328049947816898123437813,
    90: 900212494943030042797046797,
    92: 3408479268382267351010110507,
    94: 13410207519922000104514406009,
    96: 56540697284955642837798912007,
    98: 212736089539904961817389577063,
    100: 793334180624272295351382130129,
    102: 3680428259937415378335285504779,
    104: 16332602937710799037362680335351,
    106: 57831217106245162293092061499909,
    108: 248282609001868585591158742505413,
    110: 1052209925061489272435010659874991,
    112: 3787041098266201578641927407194191,
    114: 13439273072951974276382903784255637,
    116: 53125759235002964322304682027959157,
    118: 291658670780267526191653438575411491,
    120: 1153151809972770124185028131269906357,
    122: 4932188172696454339739318297923925849,
    124: 17356117513473888567381746939296160477,
    126: 70736588847140822442757134113822365169,
    128: 212537944946563703298274772990879967689,
    130: 1084744344991496578890012624928207712213,
    132: 4047187468515523114449296638529157815821,
    134: 17544816517388983161547445055372483694669,
    136: 68909661794716346033524625875715931123259,
    138: 260300599328718051119938934425302978167179,
    140: 999828801740135651717021198616667990536367,
    142: 3355483482297520282820961102046248621459173,
    144: 16631837140942852587293950352766905297528897,
    146: 85937541327755603528549497212629785145477713,
    148: 244379668284326186252863240169712092438850161,
    150: 1063901349880514705720387916171354938099705083,
    152: 4094301101616740933345553372923577469734725267,
    154: 18540363865879151504375215350972044662106182549,
    156: 74276654746024856066871733818210517618023005407,
    158: 275275419272426358674813929221957447870184635413,
    160: 1014737718417810170242113026859620408620227447581,
    162: 4478072308913255100498385793781543335816717273939,
    164: 16727777314454032963341593941190650285738385202361,
    166: 69590306463255114448417962649373740941080626000523,
    168: 315687739381804055710020885538727496795372933617227,
    170: 1267155784800316161358824961914132766229147990344997,
    172: 4010354160858905534730018630654476125957281838169269,
    174: 14153584803038660862653346883739092747954923774660251,
    176: 77432705949923513909636069140456666815340352624073251,
    178: 339852994275131877601341971143799720360724856306184203,
    180: 1179359789143995137143701718442354039063066637950737429,
    182: 4919304328219861879269200803487336608500936862015264459,
    184: 17505199067294797183746989001423060541688565870542696723,
    186: 69942997811183689049499239546127943802272331478524805397,
    188: 261274809295595261399973998023978896104786545957568559137,
    190: 1406369495880278908988444017973006804779746131711977427971,
    192: 5096174527932196609747662866401954341497716363174035275761,
    194: 17829232438088717947765479975403534458051445077992682449561,
    196: 65066066269192108839947861329734188452463615549935803519143,
    198: 349950642518780039677569542727000637357372102125566743672291,
    200: 1292650905825941096257239453478790385594125558306176183893071,
    202: 5212568709703227409964986200323079271990196603993590694680391,
    204: 24456849430211698827484825800200226142835068670603824696509853,
    206: 86484458957105177897678864034678638961222781895382346786419167,
    208: 282008119289803047168077576239866793179892385097797258038424567,
    210: 1204782513175327651249234385485579508935520775091508304137907593,
    212: 4557491279500788785092872521598135415310018444227180886738032603,
    214: 20157487867138959990956400818670113252626858623502858096773250117,
    216: 76043131885256815931216222672122360339414261530624664568946162829,
    218: 344050409069283777519808151926058652189426586409858940845468981861,
    220: 1261954136810361898882562305061560803960332696773429051013499670427,
    222: 4967098631546029459529052889119752620821846506121675016252303705879,
    224: 16820438383635236108780123377884102235161339126337922957523995233529,
    226: 89004872228161109668642757451109313028486456927748001177934114653617,
    228: 417997545002926789713327767706388156900167929618181881789066408078713,
    230: 1448119400401161666430996998583433602188054714520957809331008374203811,
    232: 6085700232501070308789059668383263517284617763227080242662586334468949,
    234: 18761475251108592243772325275525370672745869289561231704528591592371501,
    236: 75378971952862314631435911840791163346363206779933878820532663796306607,
    238: 334251059867417571197273497079020101091157708427514612078154549573744053,
    240: 1293224958516444312449612523948303217126432531171026209139782551333088281,
    242: 5936906321010438090569400987846435049778779894646896974880143196051640311,
    244: 20576188160125558108332221675210966458468072966170808188722656711461127553,
    246: 80363125512735611009514922977138951394216679592881179768811803231929707129,
    248: 371791977264476193233793691135938456442939709119625615853629510058608968387,
    250: 1042050145513045807703000231691018818256527018925081399314153802338188332967,
    252: 5279774839958419063483802629238621577728731461590896999443064285556245912531,
    254: 20335945572378210037443669733175394361807801065230296579184489046120469661507,
    256: 104343749483876530238735961449384774965065842501756473864398652143393515842787,
}

# %%
for bits in sorted(semiprimes.keys()):
    N = semiprimes[bits]
    print(f"\nFactorizing {N} (bit length: {bits})")

    # Start timing
    start_time = time.time()

    factors = shors_algorithm(N)

    # End timing
    end_time = time.time()
    runtime = end_time - start_time  # Time taken to factorize

    if factors:
        print(f"Success: {N} = {factors[0]} × {factors[1]}")
    else:
        print(f"Failed to factorize {N}.")

    # Print runtime
    print(f"Time taken to factorize {N}: {runtime:.4f} seconds")
# Out:
# Factorizing 143 (bit length: 8)
# Factorizing N=143, chosen a=98
# OrderedDict([('cp', 36), ('h', 18), ('measure', 9), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 66
# Factors found: 11, 13
# Success: 143 = 11 × 13
# Time taken to factorize 143: 0.2461 seconds
#
# Factorizing 899 (bit length: 10)
# Factorizing N=899, chosen a=188
# OrderedDict([('cp', 55), ('h', 22), ('measure', 11), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 91
# Factors found: 29, 31
# Success: 899 = 29 × 31
# Time taken to factorize 899: 0.1089 seconds
#
# Factorizing 3127 (bit length: 12)
# Factorizing N=3127, chosen a=1489
# OrderedDict([('cp', 78), ('h', 26), ('measure', 13), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 120
# Factors found: 53, 59
# Success: 3127 = 53 × 59
# Time taken to factorize 3127: 0.1352 seconds
#
# Factorizing 11009 (bit length: 14)
# Factorizing N=11009, chosen a=8206
# OrderedDict([('cp', 105), ('h', 30), ('measure', 15), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 153
# Factors found: 101, 109
# Success: 11009 = 101 × 109
# Time taken to factorize 11009: 0.1795 seconds
#
# Factorizing 47053 (bit length: 16)
# Factorizing N=47053, chosen a=15113
# OrderedDict([('cp', 136), ('h', 34), ('measure', 17), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 190
# Factors found: 211, 223
# Success: 47053 = 211 × 223
# Time taken to factorize 47053: 0.1684 seconds
#
# Factorizing 167659 (bit length: 18)
# Factorizing N=167659, chosen a=49837
# OrderedDict([('cp', 171), ('h', 38), ('measure', 19), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 231
# Factors found: 389, 431
# Success: 167659 = 389 × 431
# Time taken to factorize 167659: 0.1660 seconds
#
# Factorizing 744647 (bit length: 20)
# Factorizing N=744647, chosen a=144946
# OrderedDict([('cp', 210), ('h', 42), ('measure', 21), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 276
# Factors found: 821, 907
# Success: 744647 = 821 × 907
# Time taken to factorize 744647: 0.1885 seconds
#
# Factorizing 3036893 (bit length: 22)
# Factorizing N=3036893, chosen a=2581462
# OrderedDict([('cp', 253), ('h', 46), ('measure', 23), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 325
# Factors found: 1709, 1777
# Success: 3036893 = 1709 × 1777
# Time taken to factorize 3036893: 0.2129 seconds
#
# Factorizing 11426971 (bit length: 24)
# Factorizing N=11426971, chosen a=4098667
# OrderedDict([('cp', 300), ('h', 50), ('measure', 25), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 378
# Factors found: 3191, 3581
# Success: 11426971 = 3191 × 3581
# Time taken to factorize 11426971: 0.2724 seconds
#
# Factorizing 58949987 (bit length: 26)
# Factorizing N=58949987, chosen a=22617270
# OrderedDict([('cp', 351), ('h', 54), ('measure', 27), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 435
# Factors found: 7333, 8039
# Success: 58949987 = 7333 × 8039
# Time taken to factorize 58949987: 0.2763 seconds
#
# Factorizing 208241207 (bit length: 28)
# Factorizing N=208241207, chosen a=34801864
# OrderedDict([('cp', 403), ('h', 58), ('measure', 29), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 493
# Factors found: 13241, 15727
# Success: 208241207 = 13241 × 15727
# Time taken to factorize 208241207: 0.3037 seconds
#
# Factorizing 857830637 (bit length: 30)
# Factorizing N=857830637, chosen a=236744604
# OrderedDict([('cp', 455), ('h', 62), ('measure', 31), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 551
# Factors found: 29167, 29411
# Success: 857830637 = 29167 × 29411
# Time taken to factorize 857830637: 0.3148 seconds
#
# Factorizing 2776108693 (bit length: 32)
# Factorizing N=2776108693, chosen a=770798210
# OrderedDict([('cp', 507), ('h', 66), ('measure', 33), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 609
# Factors found: 52027, 53359
# Success: 2776108693 = 52027 × 53359
# Time taken to factorize 2776108693: 0.3260 seconds
#
# Factorizing 11455067797 (bit length: 34)
# Factorizing N=11455067797, chosen a=8068424801
# OrderedDict([('cp', 559), ('h', 70), ('measure', 35), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 667
# Factors found: 104849, 109253
# Success: 11455067797 = 104849 × 109253
# Time taken to factorize 11455067797: 0.3606 seconds
#
# Factorizing 52734393667 (bit length: 36)
# Factorizing N=52734393667, chosen a=47958792011
# OrderedDict([('cp', 611), ('h', 74), ('measure', 37), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 725
# Factors found: 201437, 261791
# Success: 52734393667 = 201437 × 261791
# Time taken to factorize 52734393667: 0.3730 seconds
#
# Factorizing 171913873883 (bit length: 38)
# Factorizing N=171913873883, chosen a=36745290588
# OrderedDict([('cp', 663), ('h', 78), ('measure', 39), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 783
# Factors found: 395287, 434909
# Success: 171913873883 = 395287 × 434909
# Time taken to factorize 171913873883: 0.4334 seconds
#
# Factorizing 862463409547 (bit length: 40)
# Factorizing N=862463409547, chosen a=669225224938
# OrderedDict([('cp', 715), ('h', 82), ('measure', 41), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 841
# Factors found: 903017, 955091
# Success: 862463409547 = 903017 × 955091
# Time taken to factorize 862463409547: 0.4721 seconds
#
# Factorizing 2830354423669 (bit length: 42)
# Factorizing N=2830354423669, chosen a=568355417325
# OrderedDict([('cp', 767), ('h', 86), ('measure', 43), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 899
# Factors found: 1613279, 1754411
# Success: 2830354423669 = 1613279 × 1754411
# Time taken to factorize 2830354423669: 0.5808 seconds
#
# Factorizing 12942106192073 (bit length: 44)
# Factorizing N=12942106192073, chosen a=2973187499962
# OrderedDict([('cp', 819), ('h', 90), ('measure', 45), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 957
# Factors found: 3227507, 4009939
# Success: 12942106192073 = 3227507 × 4009939
# Time taken to factorize 12942106192073: 0.7404 seconds
#
# Factorizing 53454475917779 (bit length: 46)
# Factorizing N=53454475917779, chosen a=5309596349368
# OrderedDict([('cp', 871), ('h', 94), ('measure', 47), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1015
# Factors found: 6982463, 7655533
# Success: 53454475917779 = 6982463 × 7655533
# Time taken to factorize 53454475917779: 0.9302 seconds
#
# Factorizing 255975740711783 (bit length: 48)
# Factorizing N=255975740711783, chosen a=8773424967933
# OrderedDict([('cp', 923), ('h', 98), ('measure', 49), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1073
# Factors found: 15694933, 16309451
# Success: 255975740711783 = 15694933 × 16309451
# Time taken to factorize 255975740711783: 1.5827 seconds
#
# Factorizing 696252032788709 (bit length: 50)
# Factorizing N=696252032788709, chosen a=483168694478629
# OrderedDict([('cp', 975), ('h', 102), ('measure', 51), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1131
# Factors found: 25270489, 27551981
# Success: 696252032788709 = 25270489 × 27551981
# Time taken to factorize 696252032788709: 2.1447 seconds
#
# Factorizing 3622511636491483 (bit length: 52)
# Factorizing N=3622511636491483, chosen a=2266379346690461
# OrderedDict([('cp', 1027), ('h', 106), ('measure', 53), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1189
# Factors found: 60070589, 60304247
# Success: 3622511636491483 = 60070589 × 60304247
# Time taken to factorize 3622511636491483: 4.3875 seconds
#
# Factorizing 15631190744806271 (bit length: 54)
# Factorizing N=15631190744806271, chosen a=6253327902074228
# OrderedDict([('cp', 1079), ('h', 110), ('measure', 55), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1247
# Factors found: 122598937, 127498583
# Success: 15631190744806271 = 122598937 × 127498583
# Time taken to factorize 15631190744806271: 9.1336 seconds
#
# Factorizing 51326462028714137 (bit length: 56)
# Factorizing N=51326462028714137, chosen a=49436525792885163
# OrderedDict([('cp', 1131), ('h', 114), ('measure', 57), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1305
# Factors found: 212423051, 241623787
# Success: 51326462028714137 = 212423051 × 241623787
# Time taken to factorize 51326462028714137: 14.7198 seconds
#
# Factorizing 217320198167105543 (bit length: 58)
# Factorizing N=217320198167105543, chosen a=66846577733753692
# OrderedDict([('cp', 1183), ('h', 118), ('measure', 59), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1363
# Factors found: 433609129, 501189167
# Success: 217320198167105543 = 433609129 × 501189167
# Time taken to factorize 217320198167105543: 28.2441 seconds
#
# Factorizing 827414216976034907 (bit length: 60)
# Factorizing N=827414216976034907, chosen a=707365132315321237
# OrderedDict([('cp', 1235), ('h', 122), ('measure', 61), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1421
# Factors found: 896676269, 922756903
# Success: 827414216976034907 = 896676269 × 922756903
# Time taken to factorize 827414216976034907: 65.8450 seconds
#
# Factorizing 3594396771839811733 (bit length: 62)
# Factorizing N=3594396771839811733, chosen a=1987880452553042537
# OrderedDict([('cp', 1287), ('h', 126), ('measure', 63), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1479
# Factors found: 1763095459, 2038685287
# Success: 3594396771839811733 = 1763095459 × 2038685287
# Time taken to factorize 3594396771839811733: 176.4887 seconds
#
# Factorizing 13489534701147995111 (bit length: 64)
# Factorizing N=13489534701147995111, chosen a=7938653551263013536
# OrderedDict([('cp', 1339), ('h', 130), ('measure', 65), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1537
# Factors found: 3258784873, 4139437007
# Success: 13489534701147995111 = 3258784873 × 4139437007
# Time taken to factorize 13489534701147995111: 411.5027 seconds
#
# Factorizing 48998116978431560767 (bit length: 66)
# Factorizing N=48998116978431560767, chosen a=18637046770049211516
# OrderedDict([('cp', 1391), ('h', 134), ('measure', 67), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1595
# Factors found: 6520568657, 7514393231
# Success: 48998116978431560767 = 6520568657 × 7514393231
# Time taken to factorize 48998116978431560767: 844.5752 seconds
#
# Factorizing 220295379750460962499 (bit length: 68)
# Factorizing N=220295379750460962499, chosen a=69663372843975066388
# OrderedDict([('cp', 1443), ('h', 138), ('measure', 69), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1653
# Factors found: 13423982749, 16410582751
# Success: 220295379750460962499 = 13423982749 × 16410582751
# Time taken to factorize 220295379750460962499: 2103.2289 seconds
#
# Factorizing 757619317101213697553 (bit length: 70)
# Factorizing N=757619317101213697553, chosen a=267311682301092333796
# OrderedDict([('cp', 1495), ('h', 142), ('measure', 71), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1711

# %%
for bits in sorted(semiprimes.keys()):
    N = semiprimes[bits]
    print(f"\nFactorizing {N} (bit length: {bits})")

    # Start timing
    start_time = time.time()

    factors = shors_algorithm(N)

    # End timing
    end_time = time.time()
    runtime = end_time - start_time  # Time taken to factorize

    if factors:
        print(f"Success: {N} = {factors[0]} × {factors[1]}")
    else:
        print(f"Failed to factorize {N}.")

    # Print runtime
    print(f"Time taken to factorize {N}: {runtime:.4f} seconds")
# Out:
# Factorizing 757619317101213697553 (bit length: 70)
# Factorizing N=757619317101213697553, chosen a=581311052282434484773
# OrderedDict([('cp', 1495), ('h', 142), ('measure', 71), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1711
# Factors found: 26757628109, 28314143317
# Success: 757619317101213697553 = 26757628109 × 28314143317
# Time taken to factorize 757619317101213697553: 3525.5341 seconds
#
# Factorizing 4239706985407101925109 (bit length: 72)
# Factorizing N=4239706985407101925109, chosen a=3355981045177935217869
# OrderedDict([('cp', 1547), ('h', 146), ('measure', 73), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1769

# %%
for bits in sorted(semiprimes.keys()):
    N = semiprimes[bits]
    print(f"\nFactorizing {N} (bit length: {bits})")

    # Start timing
    start_time = time.time()

    factors = shors_algorithm(N)

    # End timing
    end_time = time.time()
    runtime = end_time - start_time  # Time taken to factorize

    if factors:
        print(f"Success: {N} = {factors[0]} × {factors[1]}")
    else:
        print(f"Failed to factorize {N}.")

    # Print runtime
    print(f"Time taken to factorize {N}: {runtime:.4f} seconds")
# Out:
# Factorizing 4239706985407101925109 (bit length: 72)
# Factorizing N=4239706985407101925109, chosen a=3081560828774857033562
# OrderedDict([('cp', 1547), ('h', 146), ('measure', 73), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1769
# Factors found: 63209733409, 67073641301
# Success: 4239706985407101925109 = 63209733409 × 67073641301
# Time taken to factorize 4239706985407101925109: 9079.3665 seconds
#
# Factorizing 13081178794322790282667 (bit length: 74)
# Factorizing N=13081178794322790282667, chosen a=4902863529778221240514
# OrderedDict([('cp', 1599), ('h', 150), ('measure', 75), ('cx', 2), ('barrier', 1)])
# Total Gate Count: 1827
